# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### Most New Yorkers try to avoid rats. NYC’s 'rat daddy' goes looking for them.

# %% [markdown]
# 1. Go to the New Data Portal: https://opendata.cityofnewyork.us/
# 2. Find each dataset. 311 requests and Rat inspections.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
## This will take a while, you're import 2.5 million rows
inspections = pd.read_csv(r'https://data.cityofnewyork.us/resource/erm2-nwe9.csv')

# %%
# query NYC 311 for complaint types with Rodent in the title
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote("SELECT * WHERE complaint_type = 'Rodent' LIMIT 1000000")

# %%
rat_requests = pd.read_csv(query)

# %%
rat_requests.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60821414  2024-04-10T00:17:13.000         NaN  DOHMH
# 1    60816204  2024-04-10T00:14:39.000         NaN  DOHMH
# 2    60822700  2024-04-10T00:07:13.000         NaN  DOHMH
# 3    60824082  2024-04-09T23:54:02.000         NaN  DOHMH
# 4    60824089  2024-04-09T23:41:39.000         NaN  DOHMH
#
#                                agency_name complaint_type        descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent    Mouse Sighting
# 4  Department of Health and Mental Hygiene         Rodent  Signs of Rodents
#
#              location_type  incident_zip      incident_address  ...  \
# 0  3+ Family Apt. Building       10452.0  1450 TOWNSEND AVENUE  ...
# 1  3+ Family Apt. Building       10452.0  1466 TOWNSEND AVENUE  ...
# 2  3+ Family Apt. Building       10452.0   50 EAST  172 STREET  ...
# 3  3+ Family Apt. Building       10034.0      97 SEAMAN AVENUE  ...
# 4  3+ Family Apt. Building       11208.0   375 FOUNTAIN AVENUE  ...
#
#   vehicle_type taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.841119
# 1                      NaN       NaN                    NaN  40.841350
# 2                      NaN       NaN                    NaN  40.841904
# 3                      NaN       NaN                    NaN  40.868268
# 4                      NaN       NaN                    NaN  40.670229
#
#    longitude                                         location
# 0 -73.915893   \n,  \n(40.84111937693655, -73.91589259915179)
# 1 -73.915726  \n,  \n(40.841349810978734, -73.91572605845745)
# 2 -73.915176  \n,  \n(40.841903839077396, -73.91517600632936)
# 3 -73.924554  \n,  \n(40.868267734000455, -73.92455372965492)
# 4 -73.874061   \n,  \n(40.67022900572846, -73.87406118798549)
#
# [5 rows x 41 columns]

# %%
rat_requests.sample(3)
# Out:
#         unique_key             created_date              closed_date agency  \
# 179830    42676754  2019-05-15T14:01:11.000  2019-08-29T08:17:23.000  DOHMH
# 149255    46355324  2020-06-01T06:16:30.000  2020-06-01T06:16:30.000  DOHMH
# 207100    39654268  2018-07-06T00:34:27.000  2018-07-06T00:34:27.000  DOHMH
#
#                                     agency_name complaint_type  \
# 179830  Department of Health and Mental Hygiene         Rodent
# 149255  Department of Health and Mental Hygiene         Rodent
# 207100  Department of Health and Mental Hygiene         Rodent
#
#             descriptor            location_type  incident_zip  \
# 179830  Mouse Sighting  3+ Family Apt. Building       10456.0
# 149255    Rat Sighting  3+ Family Apt. Building       10031.0
# 207100    Rat Sighting      Commercial Building       11385.0
#
#             incident_address  ... vehicle_type taxi_company_borough  \
# 179830      1187 BOSTON ROAD  ...          NaN                  NaN
# 149255         3609 BROADWAY  ...          NaN                  NaN
# 207100  1809 CORNELIA STREET  ...          NaN                  NaN
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 179830                   NaN                 NaN                      NaN
# 149255                   NaN                 NaN                      NaN
# 207100                   NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude  longitude  \
# 179830       NaN                    NaN  40.829082 -73.902842
# 149255       NaN                    NaN  40.828642 -73.948848
# 207100       NaN                    NaN  40.701302 -73.904488
#
#                                               location
# 179830  \n,  \n(40.82908179031057, -73.90284157894189)
# 149255   \n,  \n(40.8286420274815, -73.94884835932334)
# 207100  \n,  \n(40.70130167128668, -73.90448844761583)
#
# [3 rows x 41 columns]

# %%
rodent_inspections = pd.read_csv('https://data.cityofnewyork.us/resource/p937-wjvj.csv')

# %%
rodent_inspections.head()
# Out:
#   inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 0            BAIT                      2420070  PC6991299             5
# 1         Initial                     11406326  PC6813202             1
# 2         Initial                     12222288  PC7516872             1
# 3         Initial                     12239993  PC6377469             1
# 4         Initial                     12233618  PC6354936             1
#
#             bbl  boro_code  block  lot house_number      street_name  ...  \
# 0  3.032570e+09          3   3257   40          187  STANHOPE STREET  ...
# 1  2.033190e+09          2   3319   83           18  EAST 199 STREET  ...
# 2  4.014350e+09          4   1435   11        33-14        88 STREET  ...
# 3  1.009110e+09          1    911   44          238   EAST 31 STREET  ...
# 4  1.007710e+09          1    771   13          249   WEST 21 STREET  ...
#
#      borough          inspection_date              result  \
# 0   Brooklyn  2011-07-27T11:10:21.000        Bait applied
# 1      Bronx  2017-08-21T16:20:11.000  Failed for Other R
# 2     Queens  2016-12-15T13:40:26.000              Passed
# 3  Manhattan  2017-02-03T10:48:02.000              Passed
# 4  Manhattan  2017-01-24T16:46:45.000              Passed
#
#              approved_date                                    location  \
# 0  2011-07-28T08:55:41.000  \n,  \n(40.699597566116, -73.921523917539)
# 1  2017-08-28T10:05:18.000  \n,  \n(40.872205244948, -73.889583220005)
# 2  2016-12-22T09:46:48.000    \n,  \n(40.7555820309, -73.879695997579)
# 3  2017-02-08T11:38:12.000  \n,  \n(40.743401453354, -73.978545580187)
# 4  2017-01-25T11:54:13.000  \n,  \n(40.743540684853, -73.998300243426)
#
#   community_board council_district census_tract        bin  \
# 0             4.0             37.0        431.0  3074157.0
# 1             7.0             14.0      40701.0  2017598.0
# 2             3.0             25.0        279.0  4035343.0
# 3             6.0              2.0       7002.0  1019961.0
# 4             4.0              3.0         87.0  1014067.0
#
#                     nta
# 0       Bushwick (West)
# 1          Bedford Park
# 2       Jackson Heights
# 3  Murray Hill-Kips Bay
# 4  Chelsea-Hudson Yards
#
# [5 rows x 25 columns]

# %%
rodent_inspections.head()
# Out:
#   inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 0         Initial                     11446939  PC6875814             1
# 1         Initial                     12405339  PC7177834             1
# 2         Initial                     13127942  PC7562110             1
# 3         Initial                     11802796  PC6141864             1
# 4      Compliance                     12779039  PC6070223             2
#
#             bbl  boro_code  block  lot house_number          street_name  ...  \
# 0  2.057230e+09          2   5723   66          560       KAPPOCK STREET  ...
# 1  3.012130e+09          3   1213   34         1250          DEAN STREET  ...
# 2  2.028670e+09          2   2867  125           92  WEST TREMONT AVENUE  ...
# 3  1.012440e+09          1   1244  159           84      RIVERSIDE DRIVE  ...
# 4  1.022260e+09          1   2226   13          121     VERMILYEA AVENUE  ...
#
#      borough          inspection_date        result            approved_date  \
# 0      Bronx  2018-11-14T16:25:08.000  Rat Activity  2018-11-20T07:57:40.000
# 1   Brooklyn  2018-02-23T10:51:16.000        Passed  2018-02-26T09:19:42.000
# 2      Bronx  2020-01-30T14:40:00.000  Rat Activity  2020-01-31T09:10:35.000
# 3  Manhattan  2012-03-28T10:15:35.000  Rat Activity  2012-03-29T10:40:19.000
# 4  Manhattan  2011-03-21T14:50:33.000        Passed  2011-03-23T11:58:29.000
#
#                                      location community_board  \
# 0  \n,  \n(40.878357381091, -73.917135434307)             8.0
# 1  \n,  \n(40.676756876788, -73.947958975129)             8.0
# 2  \n,  \n(40.850313810543, -73.912532919686)             5.0
# 3  \n,  \n(40.785874377881, -73.981716856721)             7.0
# 4   \n,  \n(40.86644279241, -73.921431116194)            12.0
#
#   council_district census_tract        bin  \
# 0             11.0      29302.0  2083248.0
# 1             36.0        315.0  3030377.0
# 2             14.0        217.0  2128716.0
# 3              6.0        167.0  1033764.0
# 4             10.0        293.0  1064841.0
#
#                                          nta
# 0                   Riverdale-Spuyten Duyvil
# 1                      Crown Heights (North)
# 2  University Heights (South)-Morris Heights
# 3                  Upper West Side (Central)
# 4                                     Inwood
#
# [5 rows x 25 columns]

# %%
rodent_inspections.sample(2)
# Out:
#     inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 110            BAIT                      2390161  PC6978211             4
# 507         Initial                     13647300  PC8110288             1
#
#               bbl  boro_code  block  lot house_number      street_name  ...  \
# 110  3.034130e+09          3   3413   25         1310    HALSEY STREET  ...
# 507  2.023010e+09          2   2301   13          358  EAST 139 STREET  ...
#
#       borough          inspection_date        result            approved_date  \
# 110  Brooklyn  2010-07-19T13:38:12.000  Bait applied  2010-07-21T13:40:01.000
# 507     Bronx  2023-05-18T11:47:32.000        Passed  2023-05-19T09:54:16.000
#
#                                        location community_board  \
# 110   \n,  \n(40.693962755559, -73.90711325603)             4.0
# 507  \n,  \n(40.810297940945, -73.923665126289)             1.0
#
#     council_district census_tract        bin                     nta
# 110             37.0        437.0  3078918.0         Bushwick (East)
# 507              8.0         39.0  2000000.0  Mott Haven-Port Morris
#
# [2 rows x 25 columns]
