# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### Most New Yorkers try to avoid rats. NYC’s 'rat daddy' goes looking for them.

# %% [markdown]
# 1. Go to the New Data Portal: https://opendata.cityofnewyork.us/
# 2. Find each dataset. 311 requests and Rat inspections.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
## This will take a while, you're import 2.5 million rows
inspections = pd.read_csv(r'https://data.cityofnewyork.us/resource/erm2-nwe9.csv')

# %%
# query NYC 311 for complaint types with Rodent in the title
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote("SELECT * WHERE complaint_type = 'Rodent' LIMIT 1000000")

# %%
rat_requests = pd.read_csv(query)

# %%
rat_requests.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60828915  2024-04-11T00:03:12.000         NaN  DOHMH
# 1    60825376  2024-04-10T23:52:45.000         NaN  DOHMH
# 2    60828903  2024-04-10T23:46:22.000         NaN  DOHMH
# 3    60827717  2024-04-10T23:23:39.000         NaN  DOHMH
# 4    60831408  2024-04-10T22:51:19.000         NaN  DOHMH
#
#                                agency_name complaint_type        descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent    Mouse Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Signs of Rodents
# 4  Department of Health and Mental Hygiene         Rodent      Rat Sighting
#
#              location_type  incident_zip    incident_address  ...  \
# 0    Other (Explain Below)       11419.0   104-24 108 STREET  ...
# 1    Other (Explain Below)       10025.0  8 WEST  103 STREET  ...
# 2      1-2 Family Dwelling       11419.0   104-12 122 STREET  ...
# 3  3+ Family Apt. Building       11377.0     42-21 68 STREET  ...
# 4  3+ Family Apt. Building       11220.0       422 45 STREET  ...
#
#   vehicle_type taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.682891
# 1                      NaN       NaN                    NaN  40.796339
# 2                      NaN       NaN                    NaN  40.686903
# 3                      NaN       NaN                    NaN  40.742370
# 4                      NaN       NaN                    NaN  40.648817
#
#    longitude                                         location
# 0 -73.833407   \n,  \n(40.682891136108275, -73.8334065370127)
# 1 -73.962002   \n,  \n(40.79633899288401, -73.96200160679493)
# 2 -73.821469  \n,  \n(40.686902566361475, -73.82146869188188)
# 3 -73.896480   \n,  \n(40.74237008457307, -73.89647950178822)
# 4 -74.008934   \n,  \n(40.648816943257344, -74.0089335359965)
#
# [5 rows x 41 columns]

# %%
rat_requests.tail()
# Out:
#         unique_key             created_date closed_date agency  \
# 430814    15633897  2010-01-01T12:12:04.000         NaN  DOHMH
# 430815    15633896  2010-01-01T12:11:51.000         NaN  DOHMH
# 430816    15633965  2010-01-01T12:11:44.000         NaN  DOHMH
# 430817    15633054  2010-01-01T11:20:45.000         NaN  DOHMH
# 430818    15633803  2010-01-01T08:29:58.000         NaN  DOHMH
#
#                                     agency_name complaint_type  \
# 430814  Department of Health and Mental Hygiene         Rodent
# 430815  Department of Health and Mental Hygiene         Rodent
# 430816  Department of Health and Mental Hygiene         Rodent
# 430817  Department of Health and Mental Hygiene         Rodent
# 430818  Department of Health and Mental Hygiene         Rodent
#
#                           descriptor            location_type  incident_zip  \
# 430814                  Rat Sighting  3+ Family Apt. Building       10458.0
# 430815                  Rat Sighting  3+ Family Apt. Building       10027.0
# 430816  Condition Attracting Rodents      1-2 Family Dwelling       11420.0
# 430817                  Rat Sighting      1-2 Family Dwelling       11365.0
# 430818                  Rat Sighting  3+ Family Apt. Building       11206.0
#
#             incident_address  ... vehicle_type taxi_company_borough  \
# 430814  2356 LORILLARD PLACE  ...          NaN                  NaN
# 430815   317 WEST 120 STREET  ...          NaN                  NaN
# 430816     119-27 130 STREET  ...          NaN                  NaN
# 430817      59-13 159 STREET  ...          NaN                  NaN
# 430818    202 PULASKI STREET  ...          NaN                  NaN
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 430814                   NaN                 NaN                      NaN
# 430815                   NaN                 NaN                      NaN
# 430816                   NaN                 NaN                      NaN
# 430817                   NaN                 NaN                      NaN
# 430818                   NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude  longitude  \
# 430814       NaN                    NaN  40.855513 -73.890006
# 430815       NaN                    NaN  40.807367 -73.954388
# 430816       NaN                    NaN  40.674091 -73.808377
# 430817       NaN                    NaN  40.739983 -73.809299
# 430818       NaN                    NaN  40.692989 -73.943771
#
#                                                location
# 430814   \n,  \n(40.85551279775197, -73.89000626904053)
# 430815  \n,  \n(40.807367287308594, -73.95438787024435)
# 430816   \n,  \n(40.67409083763361, -73.80837696748092)
# 430817   \n,  \n(40.73998332248969, -73.80929891501533)
# 430818   \n,  \n(40.69298896011082, -73.94377050323628)
#
# [5 rows x 41 columns]

# %%
rat_requests.sample(3)
# Out:
#         unique_key             created_date              closed_date agency  \
# 174910    43144079  2019-06-28T12:09:47.000  2019-08-29T10:05:54.000  DOHMH
# 289882    32283977  2015-12-28T00:00:00.000  2016-02-01T00:00:00.000  DOHMH
# 25650     58469384  2023-08-10T07:50:44.000  2023-08-21T10:27:10.000  DOHMH
#
#                                     agency_name complaint_type  \
# 174910  Department of Health and Mental Hygiene         Rodent
# 289882  Department of Health and Mental Hygiene         Rodent
# 25650   Department of Health and Mental Hygiene         Rodent
#
#                           descriptor            location_type  incident_zip  \
# 174910  Condition Attracting Rodents      1-2 Family Dwelling       11234.0
# 289882                  Rat Sighting  3+ Family Apt. Building       10026.0
# 25650   Condition Attracting Rodents  3+ Family Apt. Building       11106.0
#
#              incident_address  ... vehicle_type taxi_company_borough  \
# 174910        3900 KINGSHIGWY  ...          NaN                  NaN
# 289882        1370 5TH AVENUE  ...          NaN                  NaN
# 25650   31-35 CRESCENT STREET  ...          NaN                  NaN
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 174910                   NaN                 NaN                      NaN
# 289882                   NaN                 NaN                      NaN
# 25650                    NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude  longitude  \
# 174910       NaN                    NaN  40.622765 -73.936034
# 289882       NaN                    NaN  40.799312 -73.948275
# 25650        NaN                    NaN  40.764684 -73.927184
#
#                                               location
# 174910  \n,  \n(40.62276518837691, -73.93603433007436)
# 289882  \n,  \n(40.79931168069977, -73.94827494489684)
# 25650   \n,  \n(40.76468368198577, -73.92718359841146)
#
# [3 rows x 41 columns]

# %%
rodent_inspections = pd.read_csv('https://data.cityofnewyork.us/resource/p937-wjvj.csv')

# %%
rodent_inspections.head()
# Out:
#   inspection_type  job_ticket_or_work_order_id     job_id  job_progress  bbl  \
# 0         Initial                     13661515  PC8122655             1  NaN
# 1         Initial                     11507405  PC7504205             1  NaN
# 2         Initial                     13264492  PC7744572             1  NaN
# 3         Initial                     13252138  PC7732344             1  NaN
# 4         Initial                     13432908  PC7906420             1  NaN
#
#    boro_code  block  lot house_number      street_name  ...        borough  \
# 0          1    529    9          NaN              NaN  ...      Manhattan
# 1          5     62  113          000      YORK AVENUE  ...  Staten Island
# 2          2   2857   95         0000    JEROME AVENUE  ...          Bronx
# 3          2   2409   59          NaN              NaN  ...          Bronx
# 4          2   2420   78         0000  EAST 161 STREET  ...          Bronx
#
#            inspection_date              result            approved_date  \
# 0  2023-06-07T16:36:13.000              Passed  2023-06-08T10:38:30.000
# 1  2010-09-16T16:00:00.000  Failed for Other R  2010-09-17T09:47:30.000
# 2  2021-07-28T12:48:53.000              Passed  2021-07-29T13:19:32.000
# 3  2021-07-07T08:49:45.000              Passed  2021-07-08T10:18:56.000
# 4  2022-07-19T13:50:56.000              Passed  2022-07-20T11:03:35.000
#
#             location community_board council_district census_tract bin  nta
# 0                NaN             NaN              NaN          NaN NaN  NaN
# 1  \n,  \n(0.0, 0.0)             NaN              NaN          NaN NaN  NaN
# 2  \n,  \n(0.0, 0.0)             NaN              NaN          NaN NaN  NaN
# 3                NaN             NaN              NaN          NaN NaN  NaN
# 4  \n,  \n(0.0, 0.0)             NaN              NaN          NaN NaN  NaN
#
# [5 rows x 25 columns]

# %%
rodent_inspections.tail()
# Out:
#     inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 995            BAIT                      2792096  PC7634086             1
# 996         Initial                     13429679  PC7897278             1
# 997         Initial                     11493061  PC7476288             1
# 998         Initial                     11910100  PC6704986             1
# 999         Initial                     12389917  PC6413192             1
#
#      bbl  boro_code  block  lot house_number        street_name  ...  \
# 995  NaN          3   1807   13          NaN                NaN  ...
# 996  NaN          2   2506   40       EDWARD        L GRANT HWY  ...
# 997  NaN          5   7033    1          000    MASON BOULEVARD  ...
# 998  NaN          2   2949   38          705  CROTONA PARK EAST  ...
# 999  NaN          1    891   53          NaN                NaN  ...
#
#            borough          inspection_date              result  \
# 995       Brooklyn  2020-09-18T09:50:13.000        Bait applied
# 996          Bronx  2022-07-13T14:40:47.000              Passed
# 997  Staten Island  2009-10-29T16:10:22.000  Failed for Other R
# 998          Bronx  2013-04-12T12:12:44.000              Passed
# 999      Manhattan  2018-01-22T14:50:31.000              Passed
#
#                approved_date                                     location  \
# 995  2020-09-21T11:18:57.000                                          NaN
# 996  2022-07-15T07:35:23.000                                          NaN
# 997  2009-11-25T09:50:01.000                            \n,  \n(0.0, 0.0)
# 998  2013-04-18T10:36:44.000                            \n,  \n(0.0, 0.0)
# 999  2018-01-23T14:26:47.000  \n,  \n(40.7470880843516, -73.977953320146)
#
#     community_board council_district census_tract bin  nta
# 995             NaN              NaN          NaN NaN  NaN
# 996             NaN              NaN          NaN NaN  NaN
# 997             NaN              NaN          NaN NaN  NaN
# 998             NaN              NaN          NaN NaN  NaN
# 999             NaN              NaN          NaN NaN  NaN
#
# [5 rows x 25 columns]

# %%
rodent_inspections.sample(2)
# Out:
#     inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 953      Compliance                     13257571  PC7669498             2
# 653         Initial                     13587672  PC8044541             1
#
#      bbl  boro_code  block  lot house_number street_name  ...    borough  \
# 953  NaN          4   9769  101          NaN         NaN  ...     Queens
# 653  NaN          1   1792   28       SECOND      AVENUE  ...  Manhattan
#
#              inspection_date  result            approved_date  location  \
# 953  2021-07-16T13:34:53.000  Passed  2021-07-20T16:02:01.000       NaN
# 653  2023-02-24T08:48:37.000  Passed  2023-02-28T15:43:37.000       NaN
#
#     community_board council_district census_tract bin  nta
# 953             NaN              NaN          NaN NaN  NaN
# 653             NaN              NaN          NaN NaN  NaN
#
# [2 rows x 25 columns]

# %%
inspections.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60830036  2024-04-11T02:59:33.000         NaN    DOT
# 1    60827592  2024-04-11T01:50:32.000         NaN    DOT
# 2    60826651  2024-04-11T01:49:53.000         NaN   NYPD
# 3    60831504  2024-04-11T01:49:46.000         NaN   NYPD
# 4    60831499  2024-04-11T01:49:23.000         NaN   NYPD
#
#                        agency_name       complaint_type        descriptor  \
# 0     Department of Transportation     Street Condition           Pothole
# 1     Department of Transportation     Street Condition           Pothole
# 2  New York City Police Department  Noise - Residential  Loud Music/Party
# 3  New York City Police Department      Noise - Vehicle   Car/Truck Music
# 4  New York City Police Department  Noise - Residential  Banging/Pounding
#
#                 location_type  incident_zip        incident_address  ...  \
# 0                         NaN       10001.0                7 AVENUE  ...
# 1                         NaN       11372.0                     NaN  ...
# 2  Residential Building/House       10452.0      1360 NELSON AVENUE  ...
# 3             Street/Sidewalk       11377.0         32-45 69 STREET  ...
# 4  Residential Building/House       10026.0  131 ST NICHOLAS AVENUE  ...
#
#   vehicle_type taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          Van                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN        NaN
# 1                      NaN       NaN                    NaN  40.747343
# 2                      NaN       NaN                    NaN  40.841209
# 3                      NaN       NaN                    NaN  40.755420
# 4                      NaN       NaN                    NaN  40.803993
#
#    longitude                                         location
# 0        NaN                                              NaN
# 1 -73.886717   \n,  \n(40.74734262034576, -73.88671660027961)
# 2 -73.922871     \n,  \n(40.84120934061617, -73.922871329281)
# 3 -73.897708     \n,  \n(40.755419723732, -73.89770809295443)
# 4 -73.952721  \n,  \n(40.803993349077885, -73.95272139805937)
#
# [5 rows x 41 columns]

# %%
inspections.tail()
# Out:
#      unique_key             created_date              closed_date agency  \
# 995    60826074  2024-04-10T21:42:32.000  2024-04-10T22:30:27.000   NYPD
# 996    60832200  2024-04-10T21:42:16.000  2024-04-10T22:07:42.000   NYPD
# 997    60824821  2024-04-10T21:42:11.000  2024-04-10T21:46:33.000   NYPD
# 998    60833097  2024-04-10T21:42:11.000  2024-04-10T21:53:14.000   NYPD
# 999    60832057  2024-04-10T21:42:09.000  2024-04-11T01:23:26.000   NYPD
#
#                          agency_name       complaint_type        descriptor  \
# 995  New York City Police Department   Noise - Commercial  Loud Music/Party
# 996  New York City Police Department  Noise - Residential  Loud Music/Party
# 997  New York City Police Department    Illegal Fireworks               NaN
# 998  New York City Police Department      Illegal Parking   Blocked Hydrant
# 999  New York City Police Department             Drinking         In Public
#
#                   location_type  incident_zip     incident_address  ...  \
# 995         Club/Bar/Restaurant       11213.0  100 KINGSTON AVENUE  ...
# 996  Residential Building/House       10301.0     37 CORSON AVENUE  ...
# 997             Street/Sidewalk       11209.0        7215 5 AVENUE  ...
# 998             Street/Sidewalk       11370.0      31-18 82 STREET  ...
# 999            Store/Commercial       11214.0     8778 BAY PARKWAY  ...
#
#     vehicle_type taxi_company_borough taxi_pick_up_location  \
# 995          NaN                  NaN                   NaN
# 996          NaN                  NaN                   NaN
# 997          NaN                  NaN                   NaN
# 998          NaN                  NaN                   NaN
# 999          NaN                  NaN                   NaN
#
#     bridge_highway_name bridge_highway_direction road_ramp  \
# 995                 NaN                      NaN       NaN
# 996                 NaN                      NaN       NaN
# 997                 NaN                      NaN       NaN
# 998                 NaN                      NaN       NaN
# 999                 NaN                      NaN       NaN
#
#     bridge_highway_segment   latitude  longitude  \
# 995                    NaN  40.676206 -73.941567
# 996                    NaN  40.638115 -74.080065
# 997                    NaN  40.631509 -74.021797
# 998                    NaN  40.758798 -73.885968
# 999                    NaN  40.598242 -73.997670
#
#                                             location
# 995    \n,  \n(40.67620632508334, -73.9415674759704)
# 996  \n,  \n(40.638114948186825, -74.08006466067279)
# 997   \n,  \n(40.631509349132195, -74.0217966423475)
# 998   \n,  \n(40.75879846304879, -73.88596796989633)
# 999   \n,  \n(40.59824175259541, -73.99767018164435)
#
# [5 rows x 41 columns]

# %%
inspections.sample(3)
# Out:
#      unique_key             created_date              closed_date agency  \
# 461    60833002  2024-04-10T23:08:00.000                      NaN    DEP
# 224    60833194  2024-04-11T00:07:45.000  2024-04-11T00:51:02.000   NYPD
# 685    60829282  2024-04-10T22:29:00.000                      NaN    DEP
#
#                                 agency_name      complaint_type  \
# 461  Department of Environmental Protection         Air Quality
# 224         New York City Police Department  Noise - Commercial
# 685  Department of Environmental Protection               Noise
#
#                                        descriptor     location_type  \
# 461         Air: Odor/Fumes, Vehicle Idling (AD3)               NaN
# 224                                Car/Truck Horn  Store/Commercial
# 685  Noise: Construction Before/After Hours (NM1)               NaN
#
#      incident_zip      incident_address  ... vehicle_type  \
# 461       10028.0                   NaN  ...          NaN
# 224       11204.0        4315 16 AVENUE  ...          NaN
# 685       10016.0  339 EAST   38 STREET  ...          NaN
#
#     taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 461                  NaN                   NaN                 NaN
# 224                  NaN                   NaN                 NaN
# 685                  NaN                   NaN                 NaN
#
#     bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 461                      NaN       NaN                    NaN  40.778815
# 224                      NaN       NaN                    NaN  40.634249
# 685                      NaN       NaN                    NaN  40.746723
#
#      longitude                                         location
# 461 -73.956083  \n,  \n(40.778814516637816, -73.95608280319802)
# 224 -73.982151    \n,  \n(40.63424932832962, -73.9821512397831)
# 685 -73.972651   \n,  \n(40.74672261901408, -73.97265113930015)
#
# [3 rows x 41 columns]
